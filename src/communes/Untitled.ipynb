# %%
#!/usr/bin/python3
import numpy as np
import pandas as pd

import  random
import matplotlib.pyplot as plt
import overpass
#api = overpass.API()
import re
from string import punctuation
import time
import datetime
from matplotlib.backends.backend_pdf import PdfPages

################### fichier pdf ##############################
out = ' Graphiques communes'+str(datetime.datetime.now())+'.pdf'
pp = PdfPages(out)
firstPage = plt.figure(figsize=(11.69,8.27))
firstPage.clf()
txt = "Poucentage d'abstension"
firstPage.text(0.5,0.5,txt, transform=firstPage.transFigure, size=12, ha="center")
pp.savefig()


communes = pd.read_csv('../../data/raw/Presid_2017_Communes_Tour_1.csv')
bureaux = pd.read_table("../../data/raw/PR17_BVot_T1_FE (copy).txt", encoding = "ISO-8859-1", sep =';', decimal =',')
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (0,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
#fig_list = list()
#liste_communes = plt.figure()
for i in range(1,3):
    #fig_list.append(plt.figure())
    plt.figure()

    burr = bureaux[bureaux['Code du département'] == str(i)]
    plt.bar(range(0, burr.shape[0]), burr['% Abs/Ins'].sort_values())
    plt.title('Par bureaux de vote:    ' + burr['Libellé du département'].iloc[0])
    plt.xlabel('bureaux de vote')
    plt.ylabel('% Abs/Ins')
    #pp.savefig(fig_list[i-1])
    pp.savefig()
    

    #plt.show()
#pp.savefig(liste_communes)
pp.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-6495b29881b9> in <module>()
#       8     burr = bureaux[bureaux['Code du département'] == str(i)]
#       9     plt.bar(range(0, burr.shape[0]), burr['% Abs/Ins'].sort_values())
# ---> 10     plt.title('Par bureaux de vote:    ' + burr['Libellé du département'].iloc[0])
#      11     plt.xlabel('bureaux de vote')
#      12     plt.ylabel('% Abs/Ins')
#
# /home/will/.local/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /home/will/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# /home/will/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
#    1436         if key >= len_axis or key < -len_axis:
# -> 1437             raise IndexError("single positional indexer is out-of-bounds")
#    1438
#    1439     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
bureaux['Libellé du département'].iloc[0]
# Out:
# 'Ain'

# %%
bureaux[bureaux['Code du département']=='ZZ']
# Out:
#       Code du département           Libellé du département  \
# 69019                  ZZ  Français établis hors de France
# 69020                  ZZ  Français établis hors de France
# 69021                  ZZ  Français établis hors de France
# 69022                  ZZ  Français établis hors de France
# 69023                  ZZ  Français établis hors de France
# ...                   ...                              ...
# 69237                  ZZ  Français établis hors de France
# 69238                  ZZ  Français établis hors de France
# 69239                  ZZ  Français établis hors de France
# 69240                  ZZ  Français établis hors de France
# 69241                  ZZ  Français établis hors de France
#
#        Code de la circonscription Libellé de la circonscription  \
# 69019                           9          9ème circonscription
# 69020                          10         10ème circonscription
# 69021                          10         10ème circonscription
# 69022                          10         10ème circonscription
# 69023                          11         11ème circonscription
# ...                           ...                           ...
# 69237                          11         11ème circonscription
# 69238                          10         10ème circonscription
# 69239                           7          7ème circonscription
# 69240                           6          6ème circonscription
# 69241                          11         11ème circonscription
#
#        Code de la commune Libellé de la commune Code du b.vote  Inscrits  \
# 69019                   1               Abidjan              1     11294
# 69020                   2             Abou Dabi              1      3469
# 69021                   3                 Abuja              1       200
# 69022                   4                 Accra              1       637
# 69023                   5              Achgabat              1        54
# ...                   ...                   ...            ...       ...
# 69237                 226                 Wuhan              1       369
# 69238                 227               Yaounde              1      1514
# 69239                 228                Zagreb              1       655
# 69240                 229                Zurich              1     21477
# 69241                 231                Taipeh              1      1204
#
#        Abstentions  % Abs/Ins  ...  Voix.9  % Voix/Ins.9  % Voix/Exp.9  \
# 69019         6966      61.68  ...      35          0.31          0.82
# 69020         1315      37.91  ...      35          1.01          1.65
# 69021           84      42.00  ...       0          0.00          0.00
# 69022          301      47.25  ...       5          0.78          1.51
# 69023           23      42.59  ...       0          0.00          0.00
# ...            ...        ...  ...     ...           ...           ...
# 69237          129      34.96  ...       3          0.81          1.27
# 69238          800      52.84  ...       4          0.26          0.56
# 69239          401      61.22  ...       6          0.92          2.39
# 69240        11129      51.82  ...      87          0.41          0.85
# 69241          519      43.11  ...      35          2.91          5.18
#
#        N°Panneau.10  Sexe.10  Nom.10  Prénom.10  Voix.10  % Voix/Ins.10  \
# 69019            11        M  FILLON   François     1756          15.55
# 69020            11        M  FILLON   François      706          20.35
# 69021            11        M  FILLON   François       38          19.00
# 69022            11        M  FILLON   François      112          17.58
# 69023            11        M  FILLON   François        9          16.67
# ...             ...      ...     ...        ...      ...            ...
# 69237            11        M  FILLON   François       62          16.80
# 69238            11        M  FILLON   François      197          13.01
# 69239            11        M  FILLON   François       65           9.92
# 69240            11        M  FILLON   François     2893          13.47
# 69241            11        M  FILLON   François      113           9.39
#
#        % Voix/Exp.10
# 69019          40.90
# 69020          33.27
# 69021          32.76
# 69022          33.84
# 69023          29.03
# ...              ...
# 69237          26.27
# 69238          27.71
# 69239          25.90
# 69240          28.24
# 69241          16.72
#
# [223 rows x 98 columns]

# %%
str('ZZ')
# Out:
# 'ZZ'

# %%
comm = communes [communes ['Code du département'].apply(lambda x : str(x)) == str(45)]
comm
# Out:
# Empty DataFrame
# Columns: [Code du département, Libellé du département, Code de la commune, Libellé de la commune, Inscrits, Abstentions, % Abs/Ins, Votants, % Vot/Ins, Blancs, % Blancs/Ins, % Blancs/Vot, Nuls, % Nuls/Ins, % Nuls/Vot, Exprimés, % Exp/Ins, % Exp/Vot, N°Panneau, Sexe, Nom, Prénom, Voix, % Voix/Ins, % Voix/Exp, N°Panneau.1, Sexe.1, Nom.1, Prénom.1, Voix.1, % Voix/Ins.1, % Voix/Exp.1, N°Panneau.2, Sexe.2, Nom.2, Prénom.2, Voix.2, % Voix/Ins.2, % Voix/Exp.2, N°Panneau.3, Sexe.3, Nom.3, Prénom.3, Voix.3, % Voix/Ins.3, % Voix/Exp.3, N°Panneau.4, Sexe.4, Nom.4, Prénom.4, Voix.4, % Voix/Ins.4, % Voix/Exp.4, N°Panneau.5, Sexe.5, Nom.5, Prénom.5, Voix.5, % Voix/Ins.5, % Voix/Exp.5, N°Panneau.6, Sexe.6, Nom.6, Prénom.6, Voix.6, % Voix/Ins.6, % Voix/Exp.6, N°Panneau.7, Sexe.7, Nom.7, Prénom.7, Voix.7, % Voix/Ins.7, % Voix/Exp.7, N°Panneau.8, Sexe.8, Nom.8, Prénom.8, Voix.8, % Voix/Ins.8, % Voix/Exp.8, N°Panneau.9, Sexe.9, Nom.9, Prénom.9, Voix.9, % Voix/Ins.9, % Voix/Exp.9, N°Panneau.10, Sexe.10, Nom.10, Prénom.10, Voix.10, % Voix/Ins.10, % Voix/Exp.10]
# Index: []
#
# [0 rows x 95 columns]
